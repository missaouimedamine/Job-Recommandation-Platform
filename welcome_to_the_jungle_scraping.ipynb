# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import time
import datetime

# %%
def get_info(link):
    page = requests.get(link)
    soup = bs(page.text, "lxml")
    
    # Initialize all fields as "non spécifié"
    company = title = lieu = contrat = location = salaire = travail = experience = education = "Non Spécifié"
    competences = []
    date = "Non trouvé"
    debut = "non spécifié"
    
    # Try to extract company
    try:
        company = soup.find('a', attrs={'class': "sc-emIrwa Trejm"}).string
    except AttributeError:
        pass  # Keep default value
    
    # Try to extract title
    try:
        title = soup.find('section', attrs={'class': "kjbyhm-1 jLtjFq"}).find_next('h2').text
    except AttributeError:
        pass  # Keep default value

    # Try to extract location (lieu)
    try:
        lieu = soup.find('a', attrs={'class': "sc-hgRRfv jOCZOZ sc-emIrwa euWxDX sc-1cigsri-2 faxiCn"}).text
    except AttributeError:
        pass  # Keep default value
    
    # Try to extract job contract details (contrat)
    try:
        contrat = soup.find_all('div', class_="sc-bOhtcR lhgrLO")[0].text
    except (AttributeError, IndexError):
        pass  # Keep default value

    # Try to extract location, salary, work type, experience, education
    try:
        location = soup.find('i', attrs={'name': "location"}).find_next('span').text
    except AttributeError:
        pass  # Keep default value
    
    try:
        salaire=soup.find('span', attrs = {'class' : "sc-bXCLTC kJcLKT"}).next_sibling.text
        salaire=salaire.replace('\xa0',' ')
    except AttributeError:
        pass  # Keep default value

    try:
        debut = soup.find('i', attrs={'name': "clock"}).find_next('span').find_next('span').text
    except AttributeError:
        pass  # Keep default value
    
    try:
        travail = soup.find('i', attrs={'name': "remote"}).find_next('span').text
    except AttributeError:
        pass  # Keep default value

    try:
        experience = soup.find('i', attrs={'name': "experience"}).find_next('span').text
    except AttributeError:
        pass  # Keep default value

    try:
        education = soup.find('i', attrs={'name': "education"}).find_next('span').text
    except AttributeError:
        pass  # Keep default value
    
    # Extract competences
    spans = soup.find_all('div', class_="sc-bOhtcR caYWTG")
    for span in spans:
        competences.append(span.text)

    # Extract job date
    try:
        date_string = soup.find('div', attrs={'class': "sc-bXCLTC yKqsk"}).find('time').get('datetime')[:10]

# Parse the string into a datetime object
        date_obj = datetime.strptime(date_string, "%Y-%m-%d")

# Format it to the desired date format (e.g., 'Day-Month-Year')
        date = date_obj.strftime("%d-%B-%Y")
    except AttributeError:
        pass  # Keep default value
    
    # Create a list with all job details
    line = [company, title, lieu, location, date, contrat, debut, salaire, travail, competences, experience, education, link]
    return line

# %%
def get_links(job):
    links = []
    options = Options()
    options.headless = True  # Run in headless mode (no UI)
    
    driver = webdriver.Chrome(options=options)
    
    try:
        driver.get("https://www.welcometothejungle.com/fr/jobs")
        time.sleep(10)  # Wait for the page to load
        
        input_element = driver.find_element(By.ID, "search-query-field")
        input_element.send_keys(job)
        input_element.send_keys(Keys.RETURN)
        time.sleep(5)  # Allow results to load

        for i in range(2):  # Loop for pagination
            items = driver.find_elements(By.CLASS_NAME, 'ais-Hits-list-item')
            
            # Extract job links from each item
            for item in items:
                link_element = item.find_element(By.CLASS_NAME, 'iPeVkS')
                links.append(link_element.get_attribute("href"))
            
            time.sleep(5)  # Slight delay before going to the next page
            
            # Click next page
            next_buttons = driver.find_elements(By.CSS_SELECTOR, 'a.sc-IqJVf.evElzU')
            if next_buttons:
                next_buttons[-1].click()
                time.sleep(10)  # Wait for the next page to load
            else:
                break  # If no next button, exit loop

    finally:
        driver.quit()  # Ensure the driver is closed properly

    return links

# %%
def save_jobs_to_dataframe():
    # Get all job links
    job_links = get_links("data science")
    
    # List to hold all job data
    job_data = []
    
    # Loop over each link and extract job info
    for link in job_links:
        info = get_info(link)
        job_data.append(info)
    
    # Create a DataFrame
    df = pd.DataFrame(job_data, columns=['Company', 'Title', 'Lieu', 'Location', 'Date', 'Contrat', 'Debut','Salaire', 'Travail', 'Competences', 'Experience', 'Education', 'Link'])
    
    # Save to CSV (optional)
    df.to_csv('welcome.csv', index=False)
    
    return df

# Example usage
df = save_jobs_to_dataframe()

# %%
df
# Out:
#          Company                                              Title  \
# 0   Non Spécifié                  Product Manager (PM) data science
# 1   Non Spécifié      Manager in Strategy & Data Science -Hong Kong
# 2   Non Spécifié  STAGE 2025 - Stage en data science LLM (ALL GE...
# 3   Non Spécifié  Expert en Intelligence Artificielle et Data Sc...
# 4   Non Spécifié                               Data Science Manager
# 5   Non Spécifié                               Data Science manager
# 6   Non Spécifié           Responsable Data Science et Insights H/F
# 7   Non Spécifié                      Stages Data Science et IA H/F
# 8   Non Spécifié                 Global RGM Data Science Lead (M/F)
# 9   Non Spécifié  DATA SCIENCE & CONTRÔLE DES PRATIQUES COMMERCI...
# 10  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 11  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 12  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 13  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 14  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 15  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 16  Non Spécifié  Stage 2025 - Data Science et Machine Learning/...
# 17  Non Spécifié  STAGE – Ingénieur Data Science pour l'optimisa...
# 18  Non Spécifié  Manager in Marketing Analytics & Data Science ...
# 19  Non Spécifié      Responsable Data Science - CDI - Nanterre H/F
# 20  Non Spécifié  Stage en Marketing Analytics et Data Science (...
# 21  Non Spécifié       Senior Consultant in Strategy & Data Science
# 22  Non Spécifié       Junior Consultant in Strategy & Data Science
# 23  Non Spécifié  Senior Consultant in Strategy & Data Science -...
# 24  Non Spécifié                 Manager in Strategy & Data Science
# 25  Non Spécifié    Manager connaissance client et data science H/F
# 26  Non Spécifié  Junior Consultant in Strategy & Data Science -...
# 27  Non Spécifié         Consultant Senior Data Science & IA  - H/F
# 28  Non Spécifié           Consultant Data Science - Confirmé (H/F)
# 29  Non Spécifié  Data Science - Operational Research Internship...
#
#             Lieu           Location        Date       Contrat  \
# 0   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 1   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 2   Non Spécifié           Toulouse  Non trouvé  Non Spécifié
# 3   Non Spécifié     Cesson-Sévigné  Non trouvé  Non Spécifié
# 4   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 5   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 6   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 7   Non Spécifié        Saint-Aubin  Non trouvé  Non Spécifié
# 8   Non Spécifié  Neuilly-sur-Seine  Non trouvé  Non Spécifié
# 9   Non Spécifié              Paris  Non trouvé  Non Spécifié
# 10  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 11  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 12  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 13  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 14  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 15  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 16  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 17  Non Spécifié             Éragny  Non trouvé  Non Spécifié
# 18  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 19  Non Spécifié           Nanterre  Non trouvé  Non Spécifié
# 20  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 21  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 22  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 23  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 24  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 25  Non Spécifié              Niort  Non trouvé  Non Spécifié
# 26  Non Spécifié              Paris  Non trouvé  Non Spécifié
# 27  Non Spécifié               Lyon  Non trouvé  Non Spécifié
# 28  Non Spécifié   Levallois-Perret  Non trouvé  Non Spécifié
# 29  Non Spécifié              Paris  Non trouvé  Non Spécifié
#
#                 Debut          Salaire                    Travail Competences  \
# 0   30 septembre 2024     Non spécifié       Télétravail fréquent          []
# 1        non spécifié     Non spécifié       Télétravail fréquent          []
# 2        non spécifié     Non spécifié   Télétravail non autorisé          []
# 3        non spécifié     Non spécifié       Télétravail fréquent          []
# 4        non spécifié     Non spécifié       Télétravail fréquent          []
# 5        non spécifié     Non spécifié       Télétravail fréquent          []
# 6        non spécifié      70K à 90K €   Télétravail non autorisé          []
# 7        non spécifié     Non spécifié   Télétravail non autorisé          []
# 8        non spécifié     Non spécifié   Télétravail non autorisé          []
# 9        non spécifié     Non spécifié  Télétravail non renseigné          []
# 10       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 11       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 12       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 13       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 14       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 15       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 16       non spécifié  1,8K € par mois       Télétravail fréquent          []
# 17       non spécifié     Non spécifié  Télétravail non renseigné          []
# 18       non spécifié           140K $       Télétravail fréquent          []
# 19       non spécifié     Non spécifié  Télétravail non renseigné          []
# 20       non spécifié     Non spécifié       Télétravail fréquent          []
# 21       non spécifié     Non spécifié   Télétravail non autorisé          []
# 22       non spécifié     Non spécifié   Télétravail non autorisé          []
# 23       non spécifié     Non spécifié       Télétravail fréquent          []
# 24       non spécifié     Non spécifié   Télétravail non autorisé          []
# 25    02 février 2025     Non spécifié       Télétravail fréquent          []
# 26       non spécifié     Non spécifié       Télétravail fréquent          []
# 27       non spécifié     Non spécifié       Télétravail fréquent          []
# 28       non spécifié     Non spécifié  Télétravail non renseigné          []
# 29       non spécifié     Non spécifié  Télétravail non renseigné          []
#
#       Experience     Education  \
# 0   Non Spécifié  Non Spécifié
# 1   Non Spécifié  Non Spécifié
# 2   Non Spécifié  Non Spécifié
# 3   Non Spécifié  Non Spécifié
# 4   Non Spécifié  Non Spécifié
# 5   Non Spécifié  Non Spécifié
# 6   Non Spécifié  Non Spécifié
# 7   Non Spécifié  Non Spécifié
# 8   Non Spécifié  Non Spécifié
# 9   Non Spécifié  Non Spécifié
# 10  Non Spécifié  Non Spécifié
# 11  Non Spécifié  Non Spécifié
# 12  Non Spécifié  Non Spécifié
# 13  Non Spécifié  Non Spécifié
# 14  Non Spécifié  Non Spécifié
# 15  Non Spécifié  Non Spécifié
# 16  Non Spécifié  Non Spécifié
# 17  Non Spécifié  Non Spécifié
# 18  Non Spécifié  Non Spécifié
# 19  Non Spécifié  Non Spécifié
# 20  Non Spécifié  Non Spécifié
# 21  Non Spécifié  Non Spécifié
# 22  Non Spécifié  Non Spécifié
# 23  Non Spécifié  Non Spécifié
# 24  Non Spécifié  Non Spécifié
# 25  Non Spécifié  Non Spécifié
# 26  Non Spécifié  Non Spécifié
# 27  Non Spécifié  Non Spécifié
# 28  Non Spécifié  Non Spécifié
# 29  Non Spécifié  Non Spécifié
#
#                                                  Link
# 0   https://www.welcometothejungle.com/fr/companie...
# 1   https://www.welcometothejungle.com/fr/companie...
# 2   https://www.welcometothejungle.com/fr/companie...
# 3   https://www.welcometothejungle.com/fr/companie...
# 4   https://www.welcometothejungle.com/fr/companie...
# 5   https://www.welcometothejungle.com/fr/companie...
# 6   https://www.welcometothejungle.com/fr/companie...
# 7   https://www.welcometothejungle.com/fr/companie...
# 8   https://www.welcometothejungle.com/fr/companie...
# 9   https://www.welcometothejungle.com/fr/companie...
# 10  https://www.welcometothejungle.com/fr/companie...
# 11  https://www.welcometothejungle.com/fr/companie...
# 12  https://www.welcometothejungle.com/fr/companie...
# 13  https://www.welcometothejungle.com/fr/companie...
# 14  https://www.welcometothejungle.com/fr/companie...
# 15  https://www.welcometothejungle.com/fr/companie...
# 16  https://www.welcometothejungle.com/fr/companie...
# 17  https://www.welcometothejungle.com/fr/companie...
# 18  https://www.welcometothejungle.com/fr/companie...
# 19  https://www.welcometothejungle.com/fr/companie...
# 20  https://www.welcometothejungle.com/fr/companie...
# 21  https://www.welcometothejungle.com/fr/companie...
# 22  https://www.welcometothejungle.com/fr/companie...
# 23  https://www.welcometothejungle.com/fr/companie...
# 24  https://www.welcometothejungle.com/fr/companie...
# 25  https://www.welcometothejungle.com/fr/companie...
# 26  https://www.welcometothejungle.com/fr/companie...
# 27  https://www.welcometothejungle.com/fr/companie...
# 28  https://www.welcometothejungle.com/fr/companie...
# 29  https://www.welcometothejungle.com/fr/companie...
